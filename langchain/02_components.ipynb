# %%
from langchain_groq import ChatGroq
import os

# %%
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
## Without Prompt Template
response = llm.invoke(
    "Explain Artificial Intelligence in simple terms"
)

print(response.content)
# Out:
# **What is Artificial Intelligence (AI)?**
#
# Artificial Intelligence (AI) refers to the creation of computer systems that can think, learn, and act like humans. It's a way to make machines intelligent, so they can perform tasks that typically require human intelligence, such as:
#
# * Understanding language
# * Recognizing images and sounds
# * Making decisions
# * Solving problems
# * Learning from experience
#
# **How does AI work?**
#
# AI systems use a combination of algorithms, data, and computer power to achieve their goals. Here's a simplified overview:
#
# 1. **Data collection**: AI systems gather data from various sources, such as sensors, databases, or user input.
# 2. **Processing**: The data is processed using algorithms, which are like recipes for the computer to follow.
# 3. **Learning**: The AI system learns from the data, identifying patterns and relationships.
# 4. **Decision-making**: The AI system uses the learned information to make decisions or take actions.
#
# **Types of AI**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.
# 2. **General or Strong AI**: Aims to create a machine that can perform any intellectual task that a human can.
# 3. **Superintelligence**: A hypothetical AI that is significantly more intelligent than the best human minds.
#
# **Examples of AI in everyday life**
#
# 1. Virtual assistants (e.g., Siri, Alexa)
# 2. Image recognition (e.g., Facebook's facial recognition)
# 3. Self-driving cars
# 4. Personalized recommendations (e.g., Netflix, Amazon)
# 5. Chatbots and customer service bots
#
# **In summary**
#
# Artificial Intelligence is a field that creates intelligent machines that can think, learn, and act like humans. AI systems use data, algorithms, and computer power to achieve their goals, and they have many applications in our daily lives.

# %%
## But what if want tommorow about machine learning..
response = llm.invoke(
    "Explain Machine Learning in simple terms"
)

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms"
)

# %%
formatted_prompt = prompt.invoke(
    {"topic": "Artificial Intelligence"}
)

print(formatted_prompt)
# Out:
# messages=[HumanMessage(content='Explain Artificial Intelligence in simple terms', additional_kwargs={}, response_metadata={})]

# %%
formatted_prompt = prompt.invoke(
    {"topic": "Machine Learning"}
)

print(formatted_prompt)
# Out:
# messages=[HumanMessage(content='Explain Machine Learning in simple terms', additional_kwargs={}, response_metadata={})]

# %%
### Creating Our First Chain
chain = prompt | llm

# %%
response = chain.invoke(
    {"topic": "Generative AI"}
)

print(response.content)
# Out:
# **What is Generative AI?**
#
# Generative AI is a type of artificial intelligence that can create new, original content, such as:
#
# * Images (like paintings or photos)
# * Music
# * Text (like stories or articles)
# * Videos
# * Even entire conversations
#
# **How does it work?**
#
# Generative AI uses complex algorithms to learn patterns and relationships within large datasets. This allows it to generate new content that's similar in style, structure, and quality to the original data.
#
# Think of it like a very skilled artist or writer who can create new work based on their understanding of existing styles and techniques. But instead of using brushes or pens, Generative AI uses computer code and data to create its masterpieces.
#
# **Key aspects of Generative AI:**
#
# 1. **Learning from data**: Generative AI models learn from large datasets, which helps them understand patterns and relationships within the data.
# 2. **Creating new content**: The model uses this understanding to generate new, original content that's similar in style and quality to the original data.
# 3. **Improving over time**: As the model generates more content, it can learn from its mistakes and improve its performance over time.
#
# **Examples of Generative AI:**
#
# 1. **Deepfakes**: AI-generated videos or images that look like real people or events.
# 2. **Chatbots**: AI-powered chatbots that can have conversations with humans.
# 3. **Art generators**: AI models that create original artwork, such as paintings or sculptures.
# 4. **Music generators**: AI models that compose original music, such as songs or symphonies.
#
# **In summary**, Generative AI is a powerful technology that can create new, original content across various domains. Its ability to learn from data and improve over time makes it a fascinating and rapidly evolving field.

# %%
response
# Out:
# AIMessage(content="**What is Generative AI?**\n\nGenerative AI is a type of artificial intelligence that can create new, original content, such as:\n\n* Images (like paintings or photos)\n* Music\n* Text (like stories or articles)\n* Videos\n* Even entire conversations\n\n**How does it work?**\n\nGenerative AI uses complex algorithms to learn patterns and relationships within large datasets. This allows it to generate new content that's similar in style, structure, and quality to the original data.\n\nThink of it like a very skilled artist or writer who can create new work based on their understanding of existing styles and techniques. But instead of using brushes or pens, Generative AI uses computer code and data to create its masterpieces.\n\n**Key aspects of Generative AI:**\n\n1. **Learning from data**: Generative AI models learn from large datasets, which helps them understand patterns and relationships within the data.\n2. **Creating new content**: The model uses this understanding to generate new, original content that's similar in style and quality to the original data.\n3. **Improving over time**: As the model generates more content, it can learn from its mistakes and improve its performance over time.\n\n**Examples of Generative AI:**\n\n1. **Deepfakes**: AI-generated videos or images that look like real people or events.\n2. **Chatbots**: AI-powered chatbots that can have conversations with humans.\n3. **Art generators**: AI models that create original artwork, such as paintings or sculptures.\n4. **Music generators**: AI models that compose original music, such as songs or symphonies.\n\n**In summary**, Generative AI is a powerful technology that can create new, original content across various domains. Its ability to learn from data and improve over time makes it a fascinating and rapidly evolving field.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 367, 'prompt_tokens': 43, 'total_tokens': 410, 'completion_time': 0.984312284, 'completion_tokens_details': None, 'prompt_time': 0.003937137, 'prompt_tokens_details': None, 'queue_time': 0.200628341, 'total_time': 0.988249421}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ebf39-bec0-7f71-b310-303d219a97a1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 367, 'total_tokens': 410})

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
parser = StrOutputParser()

# %%
chain = prompt | llm | parser

# %%
response = chain.invoke(
    {"topic": "LangChain"}
)

print(response)
# Out:
# LangChain is an open-source framework that helps developers build applications using large language models (LLMs) like AI chatbots. Here's a simple explanation:
#
# **What does LangChain do?**
#
# LangChain allows developers to create applications that can understand and respond to human-like language inputs. It provides a set of tools and libraries that make it easier to work with LLMs, which are AI models trained on vast amounts of text data.
#
# **Key features:**
#
# 1. **Simplifies LLM integration**: LangChain provides a simple and consistent way to interact with different LLMs, making it easier to integrate them into applications.
# 2. **Provides a unified interface**: LangChain offers a unified interface for working with various LLMs, allowing developers to switch between models or use multiple models together.
# 3. **Supports multiple use cases**: LangChain can be used for a wide range of applications, such as chatbots, virtual assistants, content generation, and more.
# 4. **Flexible and customizable**: LangChain is highly customizable, allowing developers to fine-tune the framework to suit their specific needs.
#
# **How does LangChain work?**
#
# LangChain acts as a bridge between the application and the LLM. When a user interacts with the application, LangChain receives the input and sends it to the LLM for processing. The LLM generates a response, which is then sent back to the application through LangChain.
#
# **Benefits:**
#
# 1. **Faster development**: LangChain simplifies the development process, allowing developers to focus on building the application logic rather than worrying about LLM integration.
# 2. **Improved scalability**: LangChain enables developers to easily switch between different LLMs or use multiple models together, making it easier to scale applications.
# 3. **Enhanced flexibility**: LangChain provides a flexible framework that can be customized to suit various use cases and applications.
#
# Overall, LangChain is a powerful tool that simplifies the process of building applications with large language models, making it easier for developers to create innovative and interactive applications.

# %%
response
# Out:
# "LangChain is an open-source framework that helps developers build applications using large language models (LLMs) like AI chatbots. Here's a simple explanation:\n\n**What does LangChain do?**\n\nLangChain allows developers to create applications that can understand and respond to human-like language inputs. It provides a set of tools and libraries that make it easier to work with LLMs, which are AI models trained on vast amounts of text data.\n\n**Key features:**\n\n1. **Simplifies LLM integration**: LangChain provides a simple and consistent way to interact with different LLMs, making it easier to integrate them into applications.\n2. **Provides a unified interface**: LangChain offers a unified interface for working with various LLMs, allowing developers to switch between models or use multiple models together.\n3. **Supports multiple use cases**: LangChain can be used for a wide range of applications, such as chatbots, virtual assistants, content generation, and more.\n4. **Flexible and customizable**: LangChain is highly customizable, allowing developers to fine-tune the framework to suit their specific needs.\n\n**How does LangChain work?**\n\nLangChain acts as a bridge between the application and the LLM. When a user interacts with the application, LangChain receives the input and sends it to the LLM for processing. The LLM generates a response, which is then sent back to the application through LangChain.\n\n**Benefits:**\n\n1. **Faster development**: LangChain simplifies the development process, allowing developers to focus on building the application logic rather than worrying about LLM integration.\n2. **Improved scalability**: LangChain enables developers to easily switch between different LLMs or use multiple models together, making it easier to scale applications.\n3. **Enhanced flexibility**: LangChain provides a flexible framework that can be customized to suit various use cases and applications.\n\nOverall, LangChain is a powerful tool that simplifies the process of building applications with large language models, making it easier for developers to create innovative and interactive applications."
