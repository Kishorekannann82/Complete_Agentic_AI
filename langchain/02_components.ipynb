# %%
from langchain_groq import ChatGroq
import os

# %%
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
## Without Prompt Template
response = llm.invoke(
    "Explain Artificial Intelligence in simple terms"
)

print(response.content)
# Out:
# **What is Artificial Intelligence (AI)?**
#
# Artificial Intelligence is a type of computer science that enables machines to think and learn like humans. It's like creating a robot that can make decisions, solve problems, and perform tasks on its own, without being explicitly programmed.
#
# **How does AI work?**
#
# Imagine you have a child who learns to recognize objects, like a ball or a cat. The child sees many pictures of balls and cats, and eventually, they can identify them correctly. AI works in a similar way. It's trained on large amounts of data, like images, text, or sounds, which helps it learn patterns and make decisions.
#
# **Types of AI:**
#
# 1. **Narrow or Weak AI**: This type of AI is designed to perform a specific task, like playing chess or recognizing faces. It's not conscious or self-aware.
# 2. **General or Strong AI**: This type of AI is more advanced and can perform any intellectual task that a human can. It's still in the development stage and not yet widely available.
# 3. **Superintelligence**: This is a hypothetical type of AI that is significantly more intelligent than the best human minds. It's still a topic of debate and research.
#
# **AI Applications:**
#
# 1. **Virtual Assistants**: Like Siri, Google Assistant, or Alexa, which can answer questions and perform tasks.
# 2. **Image Recognition**: Like self-driving cars, which can recognize objects and navigate roads.
# 3. **Natural Language Processing**: Like chatbots, which can understand and respond to human language.
# 4. **Predictive Analytics**: Like forecasting weather or stock prices, which can help make informed decisions.
#
# **In Simple Terms:**
#
# Artificial Intelligence is a computer system that can learn, think, and make decisions like a human. It's trained on data, can perform specific tasks, and has many applications in our daily lives. As AI continues to evolve, it will likely become an integral part of our daily lives, making tasks easier, faster, and more efficient.

# %%
## But what if want tommorow about machine learning..
response = llm.invoke(
    "Explain Machine Learning in simple terms"
)

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms"
)

# %%
formatted_prompt = prompt.invoke(
    {"topic": "Artificial Intelligence"}
)

print(formatted_prompt)
# Out:
# messages=[HumanMessage(content='Explain Artificial Intelligence in simple terms', additional_kwargs={}, response_metadata={})]

# %%
formatted_prompt = prompt.invoke(
    {"topic": "Machine Learning"}
)

print(formatted_prompt)
# Out:
# messages=[HumanMessage(content='Explain Machine Learning in simple terms', additional_kwargs={}, response_metadata={})]

# %%
### Creating Our First Chain
chain = prompt | llm

# %%
response = chain.invoke(
    {"topic": "Generative AI"}
)

print(response.content)
# Out:
# **What is Generative AI?**
#
# Generative AI, also known as Generative Models, is a type of artificial intelligence that can create new, original content, such as:
#
# * Images
# * Videos
# * Music
# * Text
# * Speech
#
# It's like a super-advanced version of a computer program that can generate new things, rather than just processing existing information.
#
# **How does it work?**
#
# Generative AI uses complex algorithms and machine learning techniques to learn patterns and relationships in large datasets. This allows it to generate new content that's similar in style, structure, and quality to the original data.
#
# Think of it like a puzzle: the AI is given a set of pieces (the dataset) and uses them to create new, complete puzzles (the generated content).
#
# **Examples of Generative AI:**
#
# 1. **Art**: AI-generated portraits, landscapes, or abstract art.
# 2. **Music**: AI-composed music, such as symphonies or pop songs.
# 3. **Text**: AI-written articles, stories, or chatbot conversations.
# 4. **Images**: AI-generated product images, fashion designs, or special effects in movies.
# 5. **Speech**: AI-generated voiceovers, podcasts, or audiobooks.
#
# **What are the benefits of Generative AI?**
#
# 1. **Creativity**: Generative AI can produce novel, innovative, and sometimes surprising content.
# 2. **Efficiency**: It can automate repetitive tasks, freeing up human creatives to focus on higher-level tasks.
# 3. **Personalization**: Generative AI can create customized content tailored to individual preferences.
#
# **What are the challenges and limitations of Generative AI?**
#
# 1. **Quality and coherence**: Generated content may not always be perfect or make sense.
# 2. **Bias and fairness**: AI models can perpetuate existing biases and stereotypes.
# 3. **Copyright and ownership**: Questions arise about who owns the rights to AI-generated content.
#
# In summary, Generative AI is a powerful technology that can create new, original content, but it also raises important questions about creativity, ownership, and responsibility.

# %%
response
# Out:
# AIMessage(content="**What is Generative AI?**\n\nGenerative AI, also known as Generative Models, is a type of artificial intelligence that can create new, original content, such as:\n\n* Images\n* Videos\n* Music\n* Text\n* Speech\n\nIt's like a super-advanced version of a computer program that can generate new things, rather than just processing existing information.\n\n**How does it work?**\n\nGenerative AI uses complex algorithms and machine learning techniques to learn patterns and relationships in large datasets. This allows it to generate new content that's similar in style, structure, and quality to the original data.\n\nThink of it like a puzzle: the AI is given a set of pieces (the dataset) and uses them to create new, complete puzzles (the generated content).\n\n**Examples of Generative AI:**\n\n1. **Art**: AI-generated portraits, landscapes, or abstract art.\n2. **Music**: AI-composed music, such as symphonies or pop songs.\n3. **Text**: AI-written articles, stories, or chatbot conversations.\n4. **Images**: AI-generated product images, fashion designs, or special effects in movies.\n5. **Speech**: AI-generated voiceovers, podcasts, or audiobooks.\n\n**What are the benefits of Generative AI?**\n\n1. **Creativity**: Generative AI can produce novel, innovative, and sometimes surprising content.\n2. **Efficiency**: It can automate repetitive tasks, freeing up human creatives to focus on higher-level tasks.\n3. **Personalization**: Generative AI can create customized content tailored to individual preferences.\n\n**What are the challenges and limitations of Generative AI?**\n\n1. **Quality and coherence**: Generated content may not always be perfect or make sense.\n2. **Bias and fairness**: AI models can perpetuate existing biases and stereotypes.\n3. **Copyright and ownership**: Questions arise about who owns the rights to AI-generated content.\n\nIn summary, Generative AI is a powerful technology that can create new, original content, but it also raises important questions about creativity, ownership, and responsibility.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 424, 'prompt_tokens': 43, 'total_tokens': 467, 'completion_time': 1.200389398, 'completion_tokens_details': None, 'prompt_time': 0.002229952, 'prompt_tokens_details': None, 'queue_time': 0.049724488, 'total_time': 1.20261935}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ebf19-93ce-7900-951a-aeb9962b7641-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 424, 'total_tokens': 467})

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
parser = StrOutputParser()

# %%
chain = prompt | llm | parser

# %%
response = chain.invoke(
    {"topic": "LangChain"}
)

print(response)
# Out:
# LangChain is an open-source framework that helps developers build applications using large language models (LLMs) like AI chatbots. Here's a simple explanation:
#
# **What does LangChain do?**
#
# LangChain allows developers to create applications that can understand and respond to human-like language inputs. It provides a set of tools and libraries that make it easier to work with LLMs, which are AI models trained on vast amounts of text data.
#
# **Key features:**
#
# 1. **Simplifies LLM integration**: LangChain provides a simple and consistent way to interact with different LLMs, making it easier to integrate them into applications.
# 2. **Provides a unified interface**: LangChain offers a unified interface for working with various LLMs, allowing developers to switch between models or use multiple models together.
# 3. **Supports multiple use cases**: LangChain can be used for a wide range of applications, such as chatbots, virtual assistants, content generation, and more.
# 4. **Flexible and customizable**: LangChain is highly customizable, allowing developers to fine-tune the framework to suit their specific needs.
#
# **How does LangChain work?**
#
# LangChain acts as a bridge between the application and the LLM. When a user interacts with the application, LangChain receives the input and sends it to the LLM for processing. The LLM generates a response, which is then sent back to the application through LangChain.
#
# **Benefits:**
#
# 1. **Faster development**: LangChain simplifies the development process, allowing developers to focus on building the application logic rather than worrying about LLM integration.
# 2. **Improved scalability**: LangChain enables developers to easily switch between different LLMs or use multiple models together, making it easier to scale applications.
# 3. **Enhanced flexibility**: LangChain provides a flexible framework that can be customized to suit various use cases and applications.
#
# Overall, LangChain is a powerful tool that simplifies the process of building applications with large language models, making it easier for developers to create innovative and interactive applications.

# %%
response
# Out:
# "LangChain is an open-source framework that helps developers build applications using large language models (LLMs) like AI chatbots. Here's a simple explanation:\n\n**What does LangChain do?**\n\nLangChain allows developers to create applications that can understand and respond to human-like language inputs. It provides a set of tools and libraries that make it easier to work with LLMs, which are AI models trained on vast amounts of text data.\n\n**Key features:**\n\n1. **Simplifies LLM integration**: LangChain provides a simple and consistent way to interact with different LLMs, making it easier to integrate them into applications.\n2. **Provides a unified interface**: LangChain offers a unified interface for working with various LLMs, allowing developers to switch between models or use multiple models together.\n3. **Supports multiple use cases**: LangChain can be used for a wide range of applications, such as chatbots, virtual assistants, content generation, and more.\n4. **Flexible and customizable**: LangChain is highly customizable, allowing developers to fine-tune the framework to suit their specific needs.\n\n**How does LangChain work?**\n\nLangChain acts as a bridge between the application and the LLM. When a user interacts with the application, LangChain receives the input and sends it to the LLM for processing. The LLM generates a response, which is then sent back to the application through LangChain.\n\n**Benefits:**\n\n1. **Faster development**: LangChain simplifies the development process, allowing developers to focus on building the application logic rather than worrying about LLM integration.\n2. **Improved scalability**: LangChain enables developers to easily switch between different LLMs or use multiple models together, making it easier to scale applications.\n3. **Enhanced flexibility**: LangChain provides a flexible framework that can be customized to suit various use cases and applications.\n\nOverall, LangChain is a powerful tool that simplifies the process of building applications with large language models, making it easier for developers to create innovative and interactive applications."
