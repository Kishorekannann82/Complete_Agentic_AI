# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
load_dotenv()
GROQ_API_KEY=os.getenv("GROQ_API_KEY")
llm=ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=GROQ_API_KEY,
    temperature=0
)

# %%
messages = [
    ("system", "You are an helpful assistant."),
    ("human", "tell me about kishorelytics"),
]
response = llm.invoke(messages)
print(response.content)
# Out:
# KishoreLytics is not a widely recognized term, and I couldn't find any information on it. It's possible that it's a proprietary or niche concept, or it could be a misspelling or variation of a different term.
#
# However, I can try to help you break down the components of the word:
#
# * "Kishore" is a common Indian surname, and it's also a term that refers to a specific age group in some Indian languages (similar to "youth" or "adolescent").
# * "Lytics" is a suffix that suggests analysis or measurement, similar to words like "analytics" or "diagnostics".
#
# If I had to take a guess, I'd say that KishoreLytics might be a term related to analytics or data analysis, possibly focused on a specific demographic or age group (e.g., youth or adolescents). However, without more context or information, it's difficult to provide a more specific or accurate explanation.
#
# ...

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('../data/kishorelytics.txt')
loaded_data = loader.load()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_16476\951990154.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loaded_data
# Out:
# [Document(metadata={'source': '../data/kishorelytics.txt'}, page_content='Kishorelytics is a technology-focused YouTube channel founded by Kishore Kannan N, \ndedicated to simplifying complex concepts in Data Analytics, Data Science, Artificial Intelligence, and Software Engineering. \nThrough step-by-step tutorials, hands-on projects, career guidance, and real-world demonstrations, \nthe channel helps students, freshers, and professionals build practical, industry-ready skills. \nKishorelytics covers a wide range of technologies, including Python, SQL, Power BI, Machine Learning, \nAI Agents, RAG, LangChain, Azure, and other modern tools.\n By delivering easy-to-understand content in both Tamil and English, the channel aims to bridge the gap\nbetween theory and real-world implementation,\nempowering learners\n to confidently build projects, prepare for interviews, and advance their careers in technology.')]

# %%
## CSV Loader
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader('../data/Titanic-Dataset.csv')
loaded_data = loader.load()

# %%
loaded_data
# Out:
# [Document(metadata={'source': '../data/Titanic-Dataset.csv', 'row': 0}, page_content='PassengerId: 1\nSurvived: 0\nPclass: 3\nName: Braund, Mr. Owen Harris\nSex: male\nAge: 22\nSibSp: 1\nParch: 0\nTicket: A/5 21171\nFare: 7.25\nCabin: \nEmbarked: S'),
#  Document(metadata={'source': '../data/Titanic-Dataset.csv', 'row': 1}, page_content='PassengerId: 2\nSurvived: 1\nPclass: 1\nName: Cumings, Mrs. John Bradley (Florence Briggs Thayer)\nSex: female\nAge: 38\nSibSp: 1\nParch: 0\nTicket: PC 17599\nFare: 71.2833\nCabin: C85\nEmbarked: C'),
#  Document(metadata={'source': '../data/Titanic-Dataset.csv', 'row': 2}, page_content='PassengerId: 3\nSurvived: 1\nPclass: 3\nName: Heikkinen, Miss. Laina\nSex: female\nAge: 26\nSibSp: 0\nParch: 0\nTicket: STON/O2. 3101282\nFare: 7.925\nCabin: \nEmbarked: S'),
# ...

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
loader = UnstructuredHTMLLoader('../data/data_loader.html')
loaded_data = loader.load()

# %%
loaded_data
# Out:
# [Document(metadata={'source': '../data/data_loader.html'}, page_content='What is a Data Loader?\n\nA Data Loader is responsible for loading data from a dataset and feeding it to a machine learning model efficiently. Instead of loading the entire dataset into memory, it loads data in small batches, making training faster and memory efficient.\n\nWhy Do We Need a Data Loader?\n\nLoads data in batches\n\nShuffles training data\n\nSupports parallel loading using multiple workers\n\nImproves GPU utilization\n\nReduces memory usage\n\nWorkflow\n\nDataset stores all samples.\n\nDataLoader reads samples.\n\nCreates mini-batches.\n\nOptionally shuffles data.\n\nFeeds batches to the model.\n\nTip: Mini-batch training is faster and more stable than processing the entire dataset at once.\n\nPyTorch Example\n\nfrom torch.utils.data import DataLoader\nfrom torchvision.datasets import MNIST\nfrom torchvision import transforms\n\ndataset = MNIST(\n    root="data",\n    train=True,\n    download=True
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('../data/report.pdf')
loaded_data = loader.load()

# %%
loaded_data
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-30T19:13:36+05:30', 'title': 'PROJECT REPORT', 'author': 'A.VASANTHARAJ', 'subject': 'PHASE I', 'moddate': '2026-03-30T19:13:36+05:30', 'source': '../data/report.pdf', 'total_pages': 57, 'page': 0, 'page_label': '1'}, page_content='KIT- KALAIGNARKARUNANIDHI \nINSTITUTE OF TECHNOLOGY \n(An Autonomous Institution, Affiliated to Anna University, Chennai) \nCoimbatore – 641402. \n \n \nA PROJECT PHASE II REPORT \n     On \n \nDesign Simulation and Testing of 3.5 GHz Band-Pass FSS \nfor 5G Application \n                                                  \n         Submitted by \n \n          AKALYA S                                 711522BEC005 \nPRASANTH A                            711522BEC080 \nNIROSHINI A                            711522BEC070 \n \nIn partial fulfilment for the award of the degree \nOf \n BACHELOR OF ENGINEERING \n                                       
# ...

# %%
loaded_data[0].page_content
# Out:
# 'KIT- KALAIGNARKARUNANIDHI \nINSTITUTE OF TECHNOLOGY \n(An Autonomous Institution, Affiliated to Anna University, Chennai) \nCoimbatore – 641402. \n \n \nA PROJECT PHASE II REPORT \n     On \n \nDesign Simulation and Testing of 3.5 GHz Band-Pass FSS \nfor 5G Application \n                                                  \n         Submitted by \n \n          AKALYA S                                 711522BEC005 \nPRASANTH A                            711522BEC080 \nNIROSHINI A                            711522BEC070 \n \nIn partial fulfilment for the award of the degree \nOf \n BACHELOR OF ENGINEERING \n                                                  IN \n          ELECTRONICS AND COMMUNICATION ENGINEERING \n  Academic Year 2025 -26 \n              \n             ANNA UNIVERSITY: CHENNAI 600 025'

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Tesla",load_max_docs=1)
loaded_data = loader.load()[0].page_content

# %%
loaded_data
# Out:
# 'Tesla, Inc. ( TEZ-lə or   TESS-lə) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures, and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services.\nThe company was incorporated in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors. Its name is a tribute to the inventor and electrical engineer Nikola Tesla. In February 2004, Elon Musk led Tesla\'s first funding round and became the company\'s chairman, subsequently claiming to be a co-founder; in 2008, he was named chief executive officer. The company began production of its first car model, the Roadster sports car, in 2008; the Model S sedan in 2012; the Model X SUV in 2015; the Model 3 sedan in 2017; the Model Y crossover in 2020; the Tesla Semi truck in 2022; and the Cybertruck pickup truck in 2023.\nTesla is one of the world\'s 
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_template = ChatPromptTemplate.from_messages(
    [
        ("human", "Answer this {question}, here is some extra {context}"),
    ]
)
messages = chat_template.format_messages(
    name="Tesla",
    question="Tell me about tesla",
    context=loaded_data
)

# %%
response= llm.invoke(messages)

# %%
response.content
# Out:
# "**Overview of Tesla, Inc.**\n\nTesla, Inc. is a multinational automotive and clean energy company headquartered in Austin, Texas. Founded in 2003 by Martin Eberhard and Marc Tarpenning, the company is named after the inventor and electrical engineer Nikola Tesla. Tesla designs, manufactures, and sells battery electric vehicles (BEVs), stationary battery energy storage devices, solar panels, and related products and services.\n\n**History**\n\n* **Founding (2003-2004)**: Tesla was incorporated on July 1, 2003, by Eberhard and Tarpenning. Elon Musk led the company's first funding round in February 2004 and became the chairman of the board.\n* **Roadster (2005-2009)**: Tesla's first car model, the Roadster sports car, was produced in 2008. Musk took an active role in the company, and the strategy was to start with a premium sports car and then move into more mainstream vehicles.\n* **Expansion (2010s)**: Tesla began production of the Model S sedan in 2012, the Model X SUV in 2015, the 
# ...
